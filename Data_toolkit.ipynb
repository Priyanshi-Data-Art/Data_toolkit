# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanshi-Data-Art/Data_toolkit/blob/main/Data_toolkit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2Using the Numpy function, generate an array of 100 evenly spaced numPers Petween 1 and 10 and
# Reshape that wD array into a 2D array

# %%
import numpy as np

# Generate an array of 100 evenly spaced numbers between 1 and 10
array_1d = np.linspace(1, 10, 100)

# Reshape the 1D array into a 2D array (for example, 10 rows and 10 columns)
array_2d = array_1d.reshape(10, 10)

# Display the resulting 2D array
print("2D Array (10 rows and 10 columns):")
print(array_2d)
# Out:
# 2D Array (10 rows and 10 columns):
# [[ 1.          1.09090909  1.18181818  1.27272727  1.36363636  1.45454545
#    1.54545455  1.63636364  1.72727273  1.81818182]
#  [ 1.90909091  2.          2.09090909  2.18181818  2.27272727  2.36363636
#    2.45454545  2.54545455  2.63636364  2.72727273]
#  [ 2.81818182  2.90909091  3.          3.09090909  3.18181818  3.27272727
#    3.36363636  3.45454545  3.54545455  3.63636364]
#  [ 3.72727273  3.81818182  3.90909091  4.          4.09090909  4.18181818
#    4.27272727  4.36363636  4.45454545  4.54545455]
#  [ 4.63636364  4.72727273  4.81818182  4.90909091  5.          5.09090909
#    5.18181818  5.27272727  5.36363636  5.45454545]
#  [ 5.54545455  5.63636364  5.72727273  5.81818182  5.90909091  6.
#    6.09090909  6.18181818  6.27272727  6.36363636]
#  [ 6.45454545  6.54545455  6.63636364  6.72727273  6.81818182  6.90909091
#    7.          7.09090909  7.18181818  7.27272727]
# ...

# %% [markdown]
#  3).Explain the following terms
#
# 1)The difference in np.array, np.asarray and np.asanyarray
#
# 2)The difference between Deep copy and shallow copyX
# short

# %% [markdown]
# np.array:
#
# Creates a new NumPy array from any object (lists, tuples, etc.).
#
# Copies the data by default, ensuring that the new array is independent of the original.

# %%
import numpy as np
arr1 = np.array([1, 2, 3])  # Creates a new array

# %% [markdown]
# np.asarray:
#
# Converts input to an array, but does not copy the data if the input is already an array of the same type.
#
# More efficient when you want to convert lists or tuples to an array without unnecessary copying.

# %%
arr2 = np.asarray(arr1)  # No copy is made if arr1 is already a NumPy array

# %% [markdown]
# np.asanyarray:
#
# Similar to np.asarray, but allows the input to be converted into any subclass of ndarray, including masked arrays and other array types.
#
# Useful when you want to ensure the output is at least an array but are okay with subclasses.

# %%
arr3 = np.asanyarray(arr1)  # Will return a subclass if the input is a subclass

# %% [markdown]
# 2. Differences between Deep Copy and Shallow Copy
# **Shallow Copy:**
#
# Creates a new object, but inserts references into it to the objects found in the original.
#
# Changes made to mutable objects in the shallow copy will reflect in the original object.
#
# Example using copy module:

# %%
import copy
original = [[1, 2, 3], [4, 5, 6]]
shallow = copy.copy(original)
shallow[0][0] = 10
print(original)  # Output: [[10, 2, 3], [4, 5, 6]] (original is affected)
# Out:
# [[10, 2, 3], [4, 5, 6]]

# %% [markdown]
# **Deep Copy:**
#
# Creates a new object and recursively adds copies of nested objects found in the original.
#
# Changes made to mutable objects in the deep copy do not affect the original object.
#
# Example using copy module:

# %%
import copy
original = [[1, 2, 3], [4, 5, 6]]
deep = copy.deepcopy(original)
deep[0][0] = 10
print(original)  # Output: [[1, 2, 3], [4, 5, 6]] (original remains unchanged)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %% [markdown]
# 4). Generate a 3*3 array with random floating-point numbers between 5and 3. Then, round each number in the array to 2 decimal places

# %%
import numpy as np

# Generate a 3x3 array with random floating-point numbers between 3 and 5
random_array = np.random.uniform(3, 5, (3, 3))

# Round each number in the array to 2 decimal places
rounded_array = np.round(random_array, 2)

random_array, rounded_array
# Out:
# (array([[4.47865689, 4.73376319, 3.5342264 ],
#         [3.09307822, 4.46943316, 4.32735683],
#         [3.60556875, 3.73777501, 4.08874956]]),
#  array([[4.48, 4.73, 3.53],
#         [3.09, 4.47, 4.33],
#         [3.61, 3.74, 4.09]]))

# %% [markdown]
# 5). Create a NumPy array with random integers Petween 1 and 10 of shape (5,6))After creating the array
# perform the following operations:
#
#  a)Extract all even integers from array.
#
#  b)Extract all odd integers from arrayX

# %%
import numpy as np

# Create a 5x6 array with random integers between 1 and 10
array = np.random.randint(1, 11, size=(5, 6))

# Print the original array
print("Original Array:")
print(array)

# a) Extract all even integers from the array
even_integers = array[array % 2 == 0]
print("\nEven Integers:")
print(even_integers)

# b) Extract all odd integers from the array
odd_integers = array[array % 2 != 0]
print("\nOdd Integers:")
print(odd_integers)
# Out:
# Original Array:
# [[ 4  5  6  5  4 10]
#  [ 4  5  8  2  2  9]
#  [10  1  9  3  7  2]
#  [ 1  9  9  2  4  5]
#  [ 8  1  3  6  3  8]]
#
# Even Integers:
# [ 4  6  4 10  4  8  2  2 10  2  2  4  8  6  8]
#
# Odd Integers:
# [5 5 5 9 1 9 3 7 1 9 9 5 1 3 3]

# %% [markdown]
# 6). Create a 3D NumPy array of shape (3,3,3) containing random integers Petween 1 and 10 Perform the
# following operations:
#
#  a) Find the indices of the maximum values along each depth level (third axis).
#
#  b) Perform elementwise multiplication of between both arrayX

# %%
import numpy as np

# Create a 3D array of shape (3, 3, 3) with random integers between 1 and 10
array = np.random.randint(1, 11, size=(3, 3, 3))

# Print the original array
print("Original 3D Array:")
print(array)

# a) Find the indices of the maximum values along each depth level (third axis)
max_indices = np.argmax(array, axis=2)
print("\nIndices of Maximum Values along each Depth Level:")
print(max_indices)

# b) Perform elementwise multiplication of the array with itself
elementwise_multiplication = array * array
print("\nElementwise Multiplication of the Array with Itself:")
print(elementwise_multiplication)
# Out:
# Original 3D Array:
# [[[10  5  1]
#   [ 7  9  4]
#   [ 3  4  4]]
#
#  [[ 7  4  3]
#   [ 7  6  1]
#   [10  8  4]]
#
#  [[ 8  8  5]
#   [10  7  6]
#   [ 6  4 10]]]
#
# Indices of Maximum Values along each Depth Level:
# [[0 1 1]
#  [0 0 0]
#  [0 0 2]]
#
# Elementwise Multiplication of the Array with Itself:
# [[[100  25   1]
#   [ 49  81  16]
#   [  9  16  16]]
#
#  [[ 49  16   9]
#   [ 49  36   1]
#   [100  64  16]]
#
#  [[ 64  64  25]
#   [100  49  36]
#   [ 36  16 100]]]

# %% [markdown]
# 7). Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and
# convert it to a numeric data type Also display the taPle attriPutes and data types of each column

# %%
import pandas as pd

# Sample dataset creation
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Phone': ['(123) 456-7890', '987-654-3210', '123.456.7890'],
    'Age': [25, 30, 35]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Display original DataFrame
print("Original DataFrame:")
print(df)

# Clean and transform the 'Phone' column
df['Phone'] = df['Phone'].str.replace(r'\D', '', regex=True)  # Remove non-numeric characters
df['Phone'] = pd.to_numeric(df['Phone'], errors='coerce')    # Convert to numeric type

# Display the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df)

# Display the attributes and data types of each column
print("\nData Types of Each Column:")
print(df.dtypes)
# Out:
# Original DataFrame:
#       Name           Phone  Age
# 0    Alice  (123) 456-7890   25
# 1      Bob    987-654-3210   30
# 2  Charlie    123.456.7890   35
#
# Cleaned DataFrame:
#       Name       Phone  Age
# 0    Alice  1234567890   25
# 1      Bob  9876543210   30
# 2  Charlie  1234567890   35
#
# Data Types of Each Column:
# Name     object
# Phone     int64
# Age       int64
# dtype: object

# %% [markdown]
# 8). Perform the following tas\s using people dataset:
#
#  a) Read the 'dataYcsv' file using pandas, skipping the first 50 rows.
#
#  b) Only read the columns: 'Last Name', ‘Gender’,’Email’,‘Phone’ and ‘Salary’ from the file.
#
#  c) Display the first 10 rows of the filtered dataset.
#
#  d) Extract the ‘Salary’' column as a Series and display its last 5 values

# %%
import pandas as pd

# Load the CSV file (make sure to upload it to the same directory)
df = pd.read_csv('People Data.csv', skiprows=50)

# Print the columns to check their names
print("Columns in the DataFrame:")
print(df.columns.tolist())

# Strip whitespace from column names
df.columns = df.columns.str.strip()

# Verify the updated column names
print("Updated Columns in the DataFrame:")
print(df.columns.tolist())

# Now filter the columns
filtered_columns = ['Last Name', 'Gender', 'Email', 'Phone', 'Salary']
try:
    df_filtered = df[filtered_columns]
    # Display the first 10 rows of the filtered dataset
    print("\nFirst 10 rows of the filtered dataset:")
    print(df_filtered.head(10))

    # Extract the 'Salary' column as a Series and display its last 5 values
    salary_series = df_filtered['Salary']
    print("\nLast 5 values of the 'Salary' column:")
    print(salary_series.tail(5))
except KeyError as e:
    print(f"Error: {e}. Please check if the column names exist.")
# Out:
# Columns in the DataFrame:
# ['50', 'afF3018e9cdd1dA', 'George', 'Mercer', 'Female', 'douglascontreras@example.net', '+1-326-669-0118x4341', '11-09-1941', 'Human resources officer', '70000']
# Updated Columns in the DataFrame:
# ['50', 'afF3018e9cdd1dA', 'George', 'Mercer', 'Female', 'douglascontreras@example.net', '+1-326-669-0118x4341', '11-09-1941', 'Human resources officer', '70000']
# Error: "None of [Index(['Last Name', 'Gender', 'Email', 'Phone', 'Salary'], dtype='object')] are in the [columns]". Please check if the column names exist.

# %% [markdown]
# 10). Create a 7*5 Dataframe in Pandas using a series generated from 35 random integers between 1 to 6)?

# %%
import pandas as pd
import numpy as np

# Generate 35 random integers between 1 and 6
random_integers = np.random.randint(1, 7, size=35)

# Reshape the array into a 7x5 format
reshaped_array = random_integers.reshape(7, 5)

# Create a DataFrame from the reshaped array
df = pd.DataFrame(reshaped_array, columns=['Col1', 'Col2', 'Col3', 'Col4', 'Col5'])

# Display the DataFrame
print(df)
# Out:
#    Col1  Col2  Col3  Col4  Col5
# 0     1     2     4     1     3
# 1     4     2     5     6     4
# 2     3     1     3     4     6
# 3     5     5     3     5     3
# 4     1     2     5     6     6
# 5     1     6     2     3     1
# 6     4     2     4     3     3

# %% [markdown]
# 11). Create two different Series, each of length 50, with the following criteria:
#
# a) The first Series should contain random numbers ranging from 10 to 50.
#
# b) The second Series should contain random numbers ranging from 100 to 1000.
#
# c) Create a DataFrame by 'joining these Series by column, and, change the names of the columns to 'col1', 'col2',
# etc&

# %%
import pandas as pd
import numpy as np

# Set a seed for reproducibility
np.random.seed(0)

# Create the first Series with random numbers ranging from 10 to 50
series1 = pd.Series(np.random.randint(10, 51, size=50))

# Create the second Series with random numbers ranging from 100 to 1000
series2 = pd.Series(np.random.randint(100, 1001, size=50))

# Create a DataFrame by joining the Series
df = pd.DataFrame({
    'col1': series1,
    'col2': series2
})

# Display the DataFrame
print(df)
# Out:
#     col1  col2
# 0     10   153
# 1     13   650
# 2     13   588
# 3     49   856
# 4     19   373
# 5     29   435
# 6     31   488
# 7     46   717
# 8     33   142
# 9     16   542
# 10    34   643
# 11    34   988
# 12    22   357
# 13    11   421
# 14    48   157
# 15    49   391
# 16    33   970
# 17    34   219
# 18    27   879
# 19    47   530
# 20    35   182
# 21    23   191
# 22    18   996
# 23    19   498
# 24    30   711
# 25    26   665
# 26    15   733
# 27    25   184
# 28    10   303
# 29    28   424
# 30    45   874
# 31    34   147
# 32    39   739
# 33    29   231
# 34    29   968
# 35    24   280
# 36    49   946
# 37    42   243
# 38    11   760
# 39    19   327
# 40    42   891
# 41    41   819
# 42    20   473
# 43    33   953
# 44    45   660
# 45    21   405
# 46    38   681
# 47    44   269
# 48    10   775
# 49    10   548

# %% [markdown]
# 13). Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the
# following tasks using Matplotlib and NumPy:
#
# a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.
#
# b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.
#
# c) Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.
#
# d) Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.
#
# e) Set the title of the plot as 'Advanced Scatter Plot of Random Values'.
#
# f) Display a legend for the scatter plot, the horizontal line, and the vertical line.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Create two NumPy arrays with 100 random float values between 0 and 1
x = np.random.rand(100)
y = np.random.rand(100)

# Step 2: Create a scatter plot
plt.scatter(x, y, color='red', marker='o', label='Data Points')

# Step 3: Add a horizontal line at y = 0.5
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')

# Step 4: Add a vertical line at x = 0.5
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')

# Step 5: Label the axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Step 6: Set the title of the plot
plt.title('Advanced Scatter Plot of Random Values')

# Step 7: Display a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Explanation of the Code:
# Import Libraries:
#
# Import NumPy for numerical operations and Matplotlib for plotting.
# Generate Random Values:
#
# Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1 using np.random.rand(100).
# Create Scatter Plot:
#
# Use plt.scatter() to create a scatter plot with red circular markers for the data points.
# Add Horizontal Line:
#
# Use plt.axhline() to add a dashed horizontal line at y = 0.5 and label it accordingly.
# Add Vertical Line:
#
# Use plt.axvline() to add a dotted vertical line at x = 0.5 and label it accordingly.
# Label Axes:
#
# Use plt.xlabel() and plt.ylabel() to label the x-axis and y-axis.
# Set Title:
#
# Use plt.title() to set the title of the plot.
# Display Legend:
#
# Use plt.legend() to display a legend for the scatter plot and the lines.
# Show Plot:
#
# Finally, use plt.show() to display the plot.

# %% [markdown]
# 14). Create a time-series dataset in a Pandas DataFrame with columns: 'Date', 'Temperature', 'Humidity' and
# Perform the following tasks using Matplotlib:
#
# a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for 'Temperature' and
# right y-axis for 'Humidity').
#
# b) Label the x-axis as 'Date'.
#
# c) Set the title of the plot as 'Temperature and Humidity Over Time'.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Step 1: Create a date range
date_range = pd.date_range(start='2023-01-01', periods=30, freq='D')

# Step 2: Create random temperature and humidity data
np.random.seed(42)  # For reproducibility
temperature = np.random.uniform(low=15, high=30, size=len(date_range))  # Random temperatures
humidity = np.random.uniform(low=40, high=100, size=len(date_range))  # Random humidity

# Step 3: Create a DataFrame
df = pd.DataFrame({
    'Date': date_range,
    'Temperature': temperature,
    'Humidity': humidity
})

# Step 4: Plot the data
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot Temperature on the left y-axis
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='tab:red')
ax1.plot(df['Date'], df['Temperature'], color='tab:red', label='Temperature')
ax1.tick_params(axis='y', labelcolor='tab:red')

# Create a second y-axis for Humidity
ax2 = ax1.twinx()
ax2.set_ylabel('Humidity (%)', color='tab:blue')
ax2.plot(df['Date'], df['Humidity'], color='tab:blue', label='Humidity')
ax2.tick_params(axis='y', labelcolor='tab:blue')

# Set the title of the plot
plt.title('Temperature and Humidity Over Time')
plt.grid()

# Show the plot
plt.show()

# %% [markdown]
# 15). Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following
# tasks using Matplotlib:
#
# a) Plot a histogram of the data with 30 bins.
#
# b) Overlay a line plot representing the normal distribution's probability density function (PDF).
#
# c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'.
#
# d) Set the title of the plot as 'Histogram with PDF Overlay'.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm

# Step 1: Create a NumPy array with 1000 samples from a normal distribution
np.random.seed(42)  # For reproducibility
data = np.random.normal(loc=0, scale=1, size=1000)  # Normal distribution with mean=0, std=1

# Step 2: Plot a histogram of the data
plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, density=True, alpha=0.6, color='g', edgecolor='black', label='Histogram')

# Step 3: Overlay the PDF of the normal distribution
xmin, xmax = plt.xlim()  # Get the x limits of the histogram
x = np.linspace(xmin, xmax, 100)  # Generate x values for PDF
p = norm.pdf(x, loc=0, scale=1)  # Calculate the PDF for the normal distribution
plt.plot(x, p, 'k', linewidth=2, label='Normal PDF')

# Step 4: Label the axes and title
plt.xlabel('Value', fontsize=14)
plt.ylabel('Frequency/Probability', fontsize=14)
plt.title('Histogram with PDF Overlay', fontsize=16)
plt.legend()  # Show the legend
plt.grid()

# Step 5: Show the plot
plt.show()

# %% [markdown]
# 17). Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the
# origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Step 1: Create two random arrays
np.random.seed(42)  # For reproducibility
x = np.random.randn(100)  # 100 random values from a normal distribution
y = np.random.randn(100)  # 100 random values from a normal distribution

# Step 2: Create a DataFrame to store the data
data = pd.DataFrame({'X': x, 'Y': y})

# Step 3: Determine the quadrant for each point
data['Quadrant'] = np.where((data['X'] > 0) & (data['Y'] > 0), 'Quadrant I',
                            np.where((data['X'] < 0) & (data['Y'] > 0), 'Quadrant II',
                                     np.where((data['X'] < 0) & (data['Y'] < 0), 'Quadrant III',
                                              'Quadrant IV')))

# Step 4: Create the scatter plot using Seaborn
plt.figure(figsize=(10, 6))
scatter_plot = sns.scatterplot(data=data, x='X', y='Y', hue='Quadrant', palette='Set1', s=100)

# Step 5: Customize the plot
plt.axhline(0, color='gray', lw=0.8, ls='--')  # Add horizontal line at y=0
plt.axvline(0, color='gray', lw=0.8, ls='--')  # Add vertical line at x=0
plt.title('Quadrant-wise Scatter Plot', fontsize=16)
plt.xlabel('X-axis', fontsize=14)
plt.ylabel('Y-axis', fontsize=14)
plt.legend(title='Quadrants')
plt.grid()

# Step 6: Show the plot
plt.show()

# %% [markdown]
# 18). With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine
# Wave Function

# %%
from math import pi
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Prepare the data
x = np.linspace(0, 2 * pi, 100)  # 100 points from 0 to 2π
y = np.sin(x)  # Sine of x

# Create a Bokeh figure
p = figure(title='Sine Wave Function', x_axis_label='X-axis', y_axis_label='Y-axis')

# Add grid lines
p.grid.grid_line_alpha = 0.5

# Plot the sine wave
p.line(x, y, line_width=2, color='blue', legend_label='sin(x)')

# Show the legend
p.legend.location = 'top_left'

# Show the plot
output_notebook()  # Use this if you're running in a Jupyter notebook
show(p)
# Out:
#   <div id="abd82508-802a-4ad0-893e-b691720c92f9" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# 19). Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their
# values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Categorical
# Bar Chart.

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HoverTool

# Generate random categorical data
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = np.random.randint(1, 100, size=len(categories))

# Create a ColumnDataSource
source = ColumnDataSource(data=dict(categories=categories, values=values))

# Create a Bokeh figure
p = figure(x_range=categories, title='Random Categorical Bar Chart',
           x_axis_label='Categories', y_axis_label='Values', height=400)  # Use height instead of plot_height

# Add bars
bars = p.vbar(x='categories', top='values', source=source, width=0.9,
              fill_color='blue', line_color='black')

# Add hover tooltips
hover = HoverTool()
hover.tooltips = [("Category", "@categories"), ("Value", "@values")]
p.add_tools(hover)

# Show the plot
output_notebook()  # Use this if you're running in a Jupyter notebook
show(p)
# Out:
#   <div id="afb25d97-110a-4f2d-82d8-62102a8b1e9f" data-root-id="p1056" style="display: contents;"></div>

# %% [markdown]
# 20). Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as
# 'Simple Line Plot

# %%
import numpy as np
import plotly.graph_objects as go

# Generate random data
np.random.seed(0)  # For reproducibility
x = np.linspace(0, 10, 100)  # 100 points from 0 to 10
y = np.random.rand(100)  # 100 random y-values

# Create a line plot
fig = go.Figure()

# Add a trace for the line
fig.add_trace(go.Scatter(x=x, y=y, mode='lines', name='Random Data'))

# Label the axes and set the title
fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X-axis',
    yaxis_title='Y-axis'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 21).Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set
# the title as 'Interactive Pie Chart'.

# %%
import numpy as np
import plotly.graph_objects as go

# Generate random data
np.random.seed(0)  # For reproducibility
labels = ['Category A', 'Category B', 'Category C', 'Category D']
values = np.random.randint(10, 100, size=len(labels))

# Create a pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values, textinfo='label+percent')])

# Set the title
fig.update_layout(title='Interactive Pie Chart')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
